# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - ETL

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this final part you will:
#
# *   Run the ETL process
# *   Extract bank and market cap data from the JSON file `bank_market_cap.json`
# *   Transform the market cap currency using the exchange rate data
# *   Load the transformed data into a seperate CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.27.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# [+] 0.0s
# opt/ibm/custom-channels/meta-wscloud/linux-64      129.0 B @   1.1MB/s  0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch         13.3kB @ 134.6MB/s  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..  ??.?MB @  ??.?MB/s 0 failed  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..   3.6kB @  46.6MB/s  0.0s
# [+] 0.1s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pkgs/main/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
# pkgs/main/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━━━ 434.2kB /  ??.?MB @   1.6MB/s  0.3s
# pkgs/main/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━━━ 360.5kB /  ??.?MB @   1.3MB/s  0.3spkgs/main/noarch                                   818.5kB @   2.3MB/s  0.4s
# [+] 0.4s
# pkgs/main/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━━━ 884.7kB /  ??.?MB @   2.4MB/s  0.4s[+] 0.5s
# pkgs/main/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━╸━   1.5MB /  ??.?MB @   3.2MB/s  0.5s[+] 0.6s
# pkgs/main/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━━━   2.1MB /  ??.?MB @   3.6MB/s  0.6s[+] 0.7s
# pkgs/main/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━━━   2.6MB /  ??.?MB @   3.8MB/s  0.7s[+] 0.8s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━━━   3.1MB /  ??.?MB @   4.0MB/s  0.8s[+] 0.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   3.7MB /  ??.?MB @   4.1MB/s  0.9s[+] 1.0s
# pkgs/main/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━━━   4.2MB /  ??.?MB @   4.2MB/s  1.0s[+] 1.1s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━━━   4.8MB /  ??.?MB @   4.3MB/s  1.1s[+] 1.2s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━━━   5.0MB /  ??.?MB @   4.4MB/s  1.2s[+] 1.3s
# pkgs/main/linux-64                                   5.1MB @   4.4MB/s  1.3s
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.*
#   - widgetsnbextension 3.5.1.*
#
#
# Transaction
#
#   Prefix: /opt/conda/envs/Python-3.9
#
#   Updating specs:
#
#    - pandas==1.3.3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                 Version  Build           Channel                                          Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + ibm-wsrt-py39t1-keep    0.0.0  0               /opt/ibm/custom-channels/meta-wscloud/noarch      2kB
#
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ibm-wsrt-py39t1-main    0.0.0  0               opt/ibm/custom-channels/meta-wscloud
#   + ibm-wsrt-py39t1-main   custom  0               /opt/ibm/custom-channels/meta-wscloud/noarch      2kB
#   - pandas                  1.3.4  py39h8c16a72_0  pkgs/main
#   + pandas                  1.3.3  py39h8c16a72_0  pkgs/main/linux-64                               10MB
#
#   Summary:
#
#   Install: 1 packages
#   Downgrade: 2 packages
#
#   Total download: 10MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━╸━   0.0 B ibm-wsrt-py39t1-keep       0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sibm-wsrt-py39t1-keep                                 2.3kB @  20.5MB/s  0.0s
# ibm-wsrt-py39t1-main                                 1.9kB @  28.8MB/s  0.0s
# [+] 0.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   4.2kB pandas                     0.1s
# Extracting   (2) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.0s[+] 0.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━  47.0kB pandas                     0.2s
# Extracting   (2) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.1s[+] 0.3s
# Downloading  (1) ━━━╸━━━━━━━━━━━━━━━━━━━   2.1MB pandas                     0.3s
# Extracting   (2) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.2s[+] 0.4s
# Downloading  (1) ━━━━━━━╸━━━━━━━━━━━━━━━   3.5MB pandas                     0.4s
# Extracting   (2) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.3s[+] 0.5s
# Downloading  (1) ━━━━━━━━━━╸━━━━━━━━━━━━   5.3MB pandas                     0.5s
# Extracting   (2) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       0.4s[+] 0.6s
# Downloading  (1) ━━━━━━━━━━━━━━━╸━━━━━━━   7.3MB pandas                     0.6s
# Extracting   (2) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       0.5s[+] 0.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━   8.5MB pandas                     0.7s
# Extracting   (2) ━━━━━━━━━━╸━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       0.6spandas                                              10.0MB @  13.8MB/s  0.7s
# [+] 0.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       0.7s[+] 0.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 pandas                     0.8s[+] 1.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 pandas                     0.9s[+] 1.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━━╸━━━━━━━━       0 pandas                     1.0s[+] 1.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 pandas                     1.1s[+] 1.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 ibm-wsrt-py39t1-keep       1.2s[+] 1.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ibm-wsrt-py39t1-keep       1.3s[+] 1.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ibm-wsrt-py39t1-keep       1.4s[+] 1.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ibm-wsrt-py39t1-keep       1.5s[+] 1.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ibm-wsrt-py39t1-main       1.6s[+] 1.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━╸━━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       1.7s[+] 1.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━╸━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       1.8s[+] 2.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       1.9s[+] 2.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 pandas                     2.0s[+] 2.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 pandas                     2.1s[+] 2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 pandas                     2.2s[+] 2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 pandas                     2.3s[+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       2.4s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       2.5s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━╸━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       2.6s[+] 2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       2.7s[+] 2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-main       2.8s[+] 3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-main       2.9s[+] 3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━━╸━━━━━━━━       0 ibm-wsrt-py39t1-main       3.0s[+] 3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 ibm-wsrt-py39t1-main       3.1s[+] 3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 pandas                     3.2s[+] 3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 pandas                     3.3s[+] 3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 pandas                     3.4s[+] 3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 pandas                     3.5s[+] 3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ibm-wsrt-py39t1-keep       3.6s[+] 3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━╸━━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       3.7s[+] 3.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━╸━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       3.8s[+] 4.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       3.9s[+] 4.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       4.0s[+] 4.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       4.1s[+] 4.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-main       4.2s[+] 4.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-main       4.3s[+] 4.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 pandas                     4.4s[+] 4.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 pandas                     4.5s[+] 4.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━╸━━━━━━━━━━━━       0 pandas                     4.6s[+] 4.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 pandas                     4.7s[+] 4.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       4.8s[+] 5.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-keep       4.9s[+] 5.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━━╸━━━━━━━━       0 ibm-wsrt-py39t1-keep       5.0s[+] 5.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 ibm-wsrt-py39t1-keep       5.1s[+] 5.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 ibm-wsrt-py39t1-main       5.2s[+] 5.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ibm-wsrt-py39t1-main       5.3s[+] 5.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ibm-wsrt-py39t1-main       5.4s[+] 5.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ibm-wsrt-py39t1-main       5.5s[+] 5.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 pandas                     5.6s[+] 5.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━╸━━━━━━━━━━━━━━━━       0 pandas                     5.7s[+] 5.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━╸━━━━━━━━━━━━━━━       0 pandas                     5.8s[+] 6.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 pandas                     5.9s[+] 6.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       6.0s[+] 6.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       6.1s[+] 6.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       6.2s[+] 6.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-keep       6.3s[+] 6.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       6.4s[+] 6.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       6.5s[+] 6.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━╸━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       6.6s[+] 6.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       6.7s[+] 6.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 pandas                     6.8s[+] 7.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 pandas                     6.9s[+] 7.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━━╸━━━━━━━━       0 pandas                     7.0s[+] 7.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 pandas                     7.1s[+] 7.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━╸━━━━━━━━━━━━━━━╸━━━━━       0 ibm-wsrt-py39t1-keep       7.2s[+] 7.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ibm-wsrt-py39t1-keep       7.3s[+] 7.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ibm-wsrt-py39t1-keep       7.4s[+] 7.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ibm-wsrt-py39t1-keep       7.5s[+] 7.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ibm-wsrt-py39t1-main       7.6s[+] 7.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━╸━━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       7.7s[+] 7.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━╸━━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       7.8s[+] 8.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-main       7.9s[+] 8.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━╸━━━━━━━━━━━━━       0 pandas                     8.0s[+] 8.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━╸━━━━━━━━━━━       0 pandas                     8.1s[+] 8.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━╸━━━━━━━━━━       0 pandas                     8.2s[+] 8.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━━━━━━╸━━━━━━━━━       0 pandas                     8.3s[+] 8.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (3) ━━━━━━━━╸━━━━━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       8.4s[+] 8.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       8.5s[+] 8.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       8.6s[+] 8.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       8.7s[+] 8.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     8.8s[+] 9.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     8.9s[+] 9.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     9.0s[+] 9.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     9.1s[+] 9.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       9.2s[+] 9.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       9.3s[+] 9.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       9.4s[+] 9.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 ibm-wsrt-py39t1-keep       9.5s[+] 9.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     9.6s[+] 9.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (2) ━━━━━━╸━━━━━━━━━━━━━━━━       1 pandas                     9.7s[+] 9.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     9.8s[+] 10.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     9.9s[+] 10.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.0s[+] 10.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.1s[+] 10.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.2s[+] 10.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.3s[+] 10.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.4s[+] 10.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.5s[+] 10.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.6s[+] 10.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.7s[+] 10.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            0.8s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                    10.8sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.27.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['requests==2.26.0']
#
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# [+] 0.0s
# opt/ibm/custom-channels/meta-wscloud/linux-64 ━━━━━━━━━━━━━━╸━━━━━   0.0 B  0.0sopt/ibm/custom-channels/meta-wscloud/linux-64       0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch         13.3kB @ 168.6MB/s  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..  ??.?MB @  ??.?MB/s 0 failed  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..   3.6kB @  59.8MB/s  0.0s
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.*
#   - widgetsnbextension 3.5.1.*
#
#
# Transaction
#
#   Prefix: /opt/conda/envs/Python-3.9
#
#   All requested packages already installed

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import glob
import pandas as pd
from datetime import datetime

# %% [markdown]
# As the exchange rate fluctuates, we will download the same dataset to make marking simpler. This will be in the same format as the dataset you used in the last section

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_1.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_2.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/exchange_rates.csv
# Out:
# --2022-12-18 18:07:41--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_1.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2815 (2.7K) [application/json]
# Saving to: ‘bank_market_cap_1.json’
#
# bank_market_cap_1.j 100%[===================>]   2.75K  --.-KB/s    in 0s
#
# 2022-12-18 18:07:41 (33.1 MB/s) - ‘bank_market_cap_1.json’ saved [2815/2815]
#
# --2022-12-18 18:07:43--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_2.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1429 (1.4K) [application/json]
# Saving to: ‘bank_market_cap_2.json’
#
# bank_market_cap_2.j 100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2022-12-18 18:07:44 (17.8 MB/s) - ‘bank_market_cap_2.json’ saved [1429/1429]
#
# --2022-12-18 18:07:45--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/exchange_rates.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 590 [text/csv]
# Saving to: ‘exchange_rates.csv’
#
# exchange_rates.csv  100%[===================>]     590  --.-KB/s    in 0s
#
# 2022-12-18 18:07:46 (7.53 MB/s) - ‘exchange_rates.csv’ saved [590/590]

# %% [markdown]
# ## Extract

# %% [markdown]
# ### JSON Extract Function
#
# This function will extract JSON files.

# %%
def extract_from_json(file_to_process):
    dataframe = pd.read_json(file_to_process)
    return dataframe

# %% [markdown]
# ## Extract Function
#
# Define the extract function that finds JSON file `bank_market_cap_1.json` and calls the function created above to extract data from them. Store the data in a `pandas` dataframe. Use the following list for the columns.

# %%
columns=['Name','Market Cap (US$ Billion)']

# %%
def extract():
    # Write your code here
    bank1 = "bank_market_cap_1.json"
    extracted_data = pd.DataFrame(columns=['Name','Market Cap (US$ Billion)'])   
    extracted_data = extracted_data.append(extract_from_json(bank1), ignore_index=True)
    
    return extracted_data
extract()
# Out:
#                                        Name  Market Cap (US$ Billion)
# 0                            JPMorgan Chase                   390.934
# 1   Industrial and Commercial Bank of China                   345.214
# 2                           Bank of America                   325.331
# 3                               Wells Fargo                   308.013
# 4                   China Construction Bank                   257.399
# ..                                      ...                       ...
# 65                             Ping An Bank                    37.993
# 66                       Standard Chartered                    37.319
# 67                     United Overseas Bank                    35.128
# 68                                QNB Group                    33.560
# 69                              Bank Rakyat                    33.081
#
# [70 rows x 2 columns]

# %% [markdown]
# <b>Question 1</b> Load the file <code>exchange_rates.csv</code> as a dataframe and find the exchange rate for British pounds with the symbol <code>GBP</code>, store it in the variable  <code>exchange_rate</code>, you will be asked for the number. Hint: set the parameter  <code>index_col</code> to 0.

# %%
# Write your code here
exch = "exchange_rates.csv"
dfcsv = pd.read_csv(exch)
dfcsv.rename( columns={'Unnamed: 0':'0'}, inplace=True )
rates = dfcsv[dfcsv['0'] == 'GBP']
rates['Rates']
# Out:
# 9    0.732398
# Name: Rates, dtype: float64

# %% [markdown]
# ## Transform
#
# Using <code>exchange_rate</code> and the `exchange_rates.csv` file find the exchange rate of USD to GBP. Write a transform function that
#
# 1.  Changes the `Market Cap (US$ Billion)` column from USD to GBP
# 2.  Rounds the Market Cap (US$ Billion)\` column to 3 decimal places
# 3.  Rename `Market Cap (US$ Billion)` to `Market Cap (GBP$ Billion)`

# %%
def transform(data):
    df = data
    df['Market Cap (US$ Billion)'] = df['Market Cap (US$ Billion)'] * float(rates['Rates'])
    df['Market Cap (US$ Billion)'] = round(df['Market Cap (US$ Billion)'] , 3)
    df.rename( columns={'Market Cap (US$ Billion)':'Market Cap (GBP$ Billion)'}, inplace=True )
    return df

# %% [markdown]
# ## Load
#
# Create a function that takes a dataframe and load it to a csv named `bank_market_cap_gbp.csv`. Make sure to set `index` to `False`.

# %%
def load(target_file, data_to_load):
    # Write your code here
    data_to_load.to_csv(target_file, index = False)

# %% [markdown]
# ## Logging Function

# %% [markdown]
# Write the logging function <code>log</code> to log your data:

# %%
def log(message):
    # Write your code here
    timestamp_format = '%Y-%h-%d-%H:%M:%S' # Year-Monthname-Day-Hour-Minute-Second
    now = datetime.now() # get current timestamp
    timestamp = now.strftime(timestamp_format)
    with open("logfile.txt","a") as f:
        f.write(timestamp + ',' + message + '\n')

# %% [markdown]
# ## Running the ETL Process

# %% [markdown]
# Log the process accordingly using the following <code>"ETL Job Started"</code> and <code>"Extract phase Started"</code>

# %%
# Write your code here
log("ETL Job Started")
log("Extract phase Started")

# %% [markdown]
# ### Extract

# %% [markdown]
# <code>Question 2</code> Use the function <code>extract</code>, and print the first 5 rows, take a screen shot:

# %%
# Call the function here
extracted_data = extract()
# Print the rows here
extracted_data.head()
# Out:
#                                       Name  Market Cap (US$ Billion)
# 0                           JPMorgan Chase                   390.934
# 1  Industrial and Commercial Bank of China                   345.214
# 2                          Bank of America                   325.331
# 3                              Wells Fargo                   308.013
# 4                  China Construction Bank                   257.399

# %% [markdown]
# Log the data as <code>"Extract phase Ended"</code>

# %%
# Write your code here
log("Extract phase Ended")

# %% [markdown]
# ### Transform

# %% [markdown]
# Log the following  <code>"Transform phase Started"</code>

# %%
# Write your code here
log("Transform phase Started")

# %% [markdown]
# <code>Question 3</code> Use the function <code>transform</code> and print the first 5 rows of the output, take a screen shot:

# %%
# Call the function here
transformed_data = transform(extracted_data)
# Print the first 5 rows here
transformed_data.head()
# Out:
#                                       Name  Market Cap (GBP$ Billion)
# 0                           JPMorgan Chase                    286.319
# 1  Industrial and Commercial Bank of China                    252.834
# 2                          Bank of America                    238.272
# 3                              Wells Fargo                    225.588
# 4                  China Construction Bank                    188.519

# %% [markdown]
# Log your data <code>"Transform phase Ended"</code>

# %%
# Write your code here
log("Transform phase Ended")

# %% [markdown]
# ### Load

# %% [markdown]
# Log the following `"Load phase Started"`.

# %%
# Write your code here
log("Load phase Sarted")

# %% [markdown]
# Call the load function

# %%
# Write your code here
load('bank_market_cap_gbp.csv', transformed_data)

# %% [markdown]
# Log the following `"Load phase Ended"`.

# %%
# Write your code here
log("Load phase Ended")

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santrcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
